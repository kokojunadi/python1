# %% [markdown]
# <a href="https://colab.research.google.com/github/kokojunadi/python1/blob/main/PKSBesitangKPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Menggunakan read_excel untuk file Excel asli
data = pd.read_excel('/content/PKS_Besitang_KPI.xls')

data.head()
# Out:
#     namakaryawan   namajabatan lokasitugas   tahun penilaian_header  \
# 0  IRWAN HARIONO  MILL MANAGER        LAMM  2025.0               S1
# 1  IRWAN HARIONO  MILL MANAGER        LAMM  2025.0               S1
# 2  IRWAN HARIONO  MILL MANAGER        LAMM  2025.0               S1
# 3  IRWAN HARIONO  MILL MANAGER        LAMM  2025.0               S1
# 4  IRWAN HARIONO  MILL MANAGER        LAMM  2025.0               S1
#
#                                              textkpi  bobot_detail1  \
# 0                                         TBS Olah              4.0
# 1                                     Produksi CPO              4.0
# 2                                   Produksi Kernel             4.0
# 3                        Pemenuhan Kapasitas Pabrik             4.0
# 4   Tingkat kesesuaian norma penggunaan bahan kimia             2.0
#
#         ket_plusminus  target_detail1 satuan_detail1    realisasi      skor  \
# 0                 NaN     75063539.00             Kg  69587124.00  0.927043
# 1                 NaN     17256944.00             Kg  15481318.00  0.897107
# 2                 NaN      3003254.00             Kg   2383832.00  0.793750
# 3                 NaN        29250.00         Kg/Jam     28414.00  0.971419
# 4  + pada hal positif            2.02         Kg/Ton         1.78  1.118812
#
#    nilaiakhir
# 0    3.708172
# 1    3.588426
# 2    3.174999
# 3    3.885675
# 4    2.237624

# %%
# 1. Menyaring data: Hanya mengambil baris yang kolom 'penilaian_header'-nya berisi 'S2'
data_s2 = data[data['penilaian_header'] == 'S2']

# 2. Membuat pivot table dari data yang sudah disaring tadi
pivot_kpi_s2 = pd.pivot_table(
    data_s2,                     # Menggunakan data_s2 yang sudah disaring
    index='textkpi',             # Row (Baris)
    columns='namakaryawan',      # Kolom
    values='target_detail1',     # Sigma Values
    aggfunc='sum',               # Menggunakan fungsi SUM (Total)
    fill_value=0                 # Mengubah data kosong menjadi 0
).reset_index()

# 3. Menampilkan hasil pivot di layar Colab
pivot_kpi_s2
# Out:
# namakaryawan                                       textkpi  ABDUL RAHIM  \
# 0                                               Biaya Lab          0.00
# 1                                            Biaya Limbah          0.00
# 2                                Biaya Tidak Langsung PKS        156.44
# 3                         Biaya VRA Kendaraan Unit Usaha           0.00
# 4                Biaya langsung PKS (Rp/ Kg Palm Product)        352.66
# ..                                                     ...          ...
# 133           Utilitas (pemanfaatan) Kenderaan unit usaha          0.00
# 134                                          Zero Accident         0.00
# 135                                         Zero Kebakaran         0.00
# 136                                        Zero Kebakaran          0.00
# 137                                             Zero Theif         0.00
#
# namakaryawan  ACHMAD SANUSI  ADITIA PRANATA  ADRIAN ARMANSHAH  AGUS HERDIANTO  \
# 0                      0.00    7.949377e+08               0.0    7.949377e+08
# 1                      0.00    1.259756e+09               0.0    1.259756e+09
# 2                    156.44    1.564400e+02               0.0    1.564400e+02
# 3                      0.00    0.000000e+00               0.0    0.000000e+00
# 4                    352.66    3.526600e+02               0.0    3.526600e+02
# ..                      ...             ...               ...             ...
# 133                    0.00    0.000000e+00               0.0    0.000000e+00
# 134                    0.00    0.000000e+00               1.0    0.000000e+00
# 135                    0.00    0.000000e+00               0.0    0.000000e+00
# 136                    0.00    0.000000e+00               1.0    0.000000e+00
# 137                    0.00    0.000000e+00               0.0    0.000000e+00
#
# namakaryawan  AGUS SALIM SIAHAAN  AHMAD HUSIN  AHMAD ISNAINI     AHMADI  ...  \
# 0                            0.0          0.0            0.0       0.00  ...
# 1                            0.0          0.0            0.0       0.00  ...
# 2                            0.0          0.0            0.0     156.44  ...
# 3                            0.0          0.0            0.0  198907.00  ...
# 4                            0.0          0.0            0.0     352.66  ...
# ..                           ...          ...            ...        ...  ...
# 133                          0.0          0.0            0.0       0.00  ...
# 134                          1.0          1.0            1.0       0.00  ...
# 135                          0.0          0.0            0.0       0.00  ...
# 136                          1.0          1.0            1.0       0.00  ...
# 137                          1.0          1.0            1.0       0.00  ...
#
# namakaryawan   SURYA DARMA  SUYONO  SWANTO MARUDUT PURBA        SYAFRI  \
# 0             7.949377e+08     0.0          0.000000e+00  0.000000e+00
# 1             1.259756e+09     0.0          1.259756e+09  1.259756e+09
# 2             1.564400e+02     0.0          1.564400e+02  1.564400e+02
# 3             0.000000e+00     0.0          0.000000e+00  0.000000e+00
# 4             3.526600e+02     0.0          3.526600e+02  3.526600e+02
# ..                     ...     ...                   ...           ...
# 133           0.000000e+00     0.0          0.000000e+00  0.000000e+00
# 134           0.000000e+00     1.0          0.000000e+00  0.000000e+00
# 135           0.000000e+00     0.0          0.000000e+00  0.000000e+00
# 136           0.000000e+00     1.0          0.000000e+00  0.000000e+00
# 137           0.000000e+00     1.0          0.000000e+00  0.000000e+00
#
# namakaryawan  SYAFRIZAL  SYAHRONI  SYAIFUL AMRI  SYAMSUL BAHRI  \
# 0                  0.00      0.00          0.00           0.00
# 1                  0.00      0.00          0.00           0.00
# 2                156.44    156.44        156.44         156.44
# 3                  0.00      0.00          0.00           0.00
# 4                352.66    352.66        352.66         352.66
# ..                  ...       ...           ...            ...
# 133                0.00      0.00          0.00           0.00
# 134                0.00      0.00          0.00           1.00
# 135                0.00      0.00          0.00           1.00
# 136                0.00      0.00          0.00           0.00
# 137                0.00      0.00          0.00           0.00
#
# namakaryawan  TIGOR PARULIAN M SINURAT  ZAMRONI
# 0                                 0.00     0.00
# 1                                 0.00     0.00
# 2                               156.44   156.44
# 3                                 0.00     0.00
# 4                               352.66   352.66
# ..                                 ...      ...
# 133                               0.00     0.00
# 134                               0.00     0.00
# 135                               0.00     0.00
# 136                               0.00     0.00
# 137                               0.00     0.00
#
# [138 rows x 111 columns]

# %%
pivot_kpi_s2.to_excel('Pivot_Target_Karyawan_PKSBesitang_S2.xlsx', index=False)

# %%
# 1. Membuat pivot table dengan Sigma Values: realisasi
pivot_realisasi_s2 = pd.pivot_table(
    data_s2,                     # Tetap menggunakan data yang sudah disaring S2
    index='textkpi',             # Row (Baris)
    columns='namakaryawan',      # Kolom ke samping
    values='realisasi',          # Sigma Values diganti menjadi kolom realisasi
    aggfunc='sum',               # Menggunakan fungsi SUM (Total)
    fill_value=0                 # Mengubah data kosong menjadi 0
).reset_index()

# 2. Menampilkan hasil pivot realisasi S2 di layar
pivot_realisasi_s2
# Out:
# namakaryawan                                       textkpi  ABDUL RAHIM  \
# 0                                               Biaya Lab          0.00
# 1                                            Biaya Limbah          0.00
# 2                                Biaya Tidak Langsung PKS        115.05
# 3                         Biaya VRA Kendaraan Unit Usaha           0.00
# 4                Biaya langsung PKS (Rp/ Kg Palm Product)        358.27
# ..                                                     ...          ...
# 133           Utilitas (pemanfaatan) Kenderaan unit usaha          0.00
# 134                                          Zero Accident         0.00
# 135                                         Zero Kebakaran         0.00
# 136                                        Zero Kebakaran          0.00
# 137                                             Zero Theif         0.00
#
# namakaryawan  ACHMAD SANUSI  ADITIA PRANATA  ADRIAN ARMANSHAH  AGUS HERDIANTO  \
# 0                      0.00    5.620705e+08               0.0    5.620705e+08
# 1                      0.00    1.643268e+08               0.0    1.643268e+08
# 2                    115.05    1.150500e+02               0.0    1.150500e+02
# 3                      0.00    0.000000e+00               0.0    0.000000e+00
# 4                    358.27    3.582700e+02               0.0    3.582700e+02
# ..                      ...             ...               ...             ...
# 133                    0.00    0.000000e+00               0.0    0.000000e+00
# 134                    0.00    0.000000e+00               1.0    0.000000e+00
# 135                    0.00    0.000000e+00               0.0    0.000000e+00
# 136                    0.00    0.000000e+00               1.0    0.000000e+00
# 137                    0.00    0.000000e+00               0.0    0.000000e+00
#
# namakaryawan  AGUS SALIM SIAHAAN  AHMAD HUSIN  AHMAD ISNAINI     AHMADI  ...  \
# 0                            0.0          0.0            0.0       0.00  ...
# 1                            0.0          0.0            0.0       0.00  ...
# 2                            0.0          0.0            0.0     115.05  ...
# 3                            0.0          0.0            0.0  223702.00  ...
# 4                            0.0          0.0            0.0     358.27  ...
# ..                           ...          ...            ...        ...  ...
# 133                          0.0          0.0            0.0       0.00  ...
# 134                          1.0          1.0            1.0       0.00  ...
# 135                          0.0          0.0            0.0       0.00  ...
# 136                          1.0          1.0            1.0       0.00  ...
# 137                          2.0          2.0            2.0       0.00  ...
#
# namakaryawan   SURYA DARMA  SUYONO  SWANTO MARUDUT PURBA        SYAFRI  \
# 0             5.620705e+08     0.0          0.000000e+00  0.000000e+00
# 1             1.643268e+08     0.0          1.643268e+08  1.643268e+08
# 2             1.150500e+02     0.0          1.150500e+02  1.150500e+02
# 3             0.000000e+00     0.0          0.000000e+00  0.000000e+00
# 4             3.582700e+02     0.0          3.582700e+02  3.582700e+02
# ..                     ...     ...                   ...           ...
# 133           0.000000e+00     0.0          0.000000e+00  0.000000e+00
# 134           0.000000e+00     1.0          0.000000e+00  0.000000e+00
# 135           0.000000e+00     0.0          0.000000e+00  0.000000e+00
# 136           0.000000e+00     1.0          0.000000e+00  0.000000e+00
# 137           0.000000e+00     2.0          0.000000e+00  0.000000e+00
#
# namakaryawan  SYAFRIZAL  SYAHRONI  SYAIFUL AMRI  SYAMSUL BAHRI  \
# 0                  0.00      0.00          0.00           0.00
# 1                  0.00      0.00          0.00           0.00
# 2                115.05    115.05        115.05         115.05
# 3                  0.00      0.00          0.00           0.00
# 4                358.27    358.27        358.27         358.27
# ..                  ...       ...           ...            ...
# 133                0.00      0.00          0.00           0.00
# 134                0.00      0.00          0.00           1.00
# 135                0.00      0.00          0.00           1.00
# 136                0.00      0.00          0.00           0.00
# 137                0.00      0.00          0.00           0.00
#
# namakaryawan  TIGOR PARULIAN M SINURAT  ZAMRONI
# 0                                 0.00     0.00
# 1                                 0.00     0.00
# 2                               115.05   115.05
# 3                                 0.00     0.00
# 4                               358.27   358.27
# ..                                 ...      ...
# 133                               0.00     0.00
# 134                               0.00     0.00
# 135                               0.00     0.00
# 136                               0.00     0.00
# 137                               0.00     0.00
#
# [138 rows x 111 columns]

# %%
pivot_realisasi_s2.to_excel('Pivot_Realisasi_Karyawan_PKSBsitang_S2.xlsx', index=False)
